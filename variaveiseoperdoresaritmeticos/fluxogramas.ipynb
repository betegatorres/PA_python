# %% [markdown]
# <a href="https://colab.research.google.com/github/betegatorres/PA_python/blob/main/variaveiseoperdoresaritmeticos/fluxogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Calculo de média
# ![image.png](data:image/png;base64,...)

# %%
#entrada
num1 = float(input("Digite sua primeira nota: "))
num2 = float(input("Digite sua segunda nota: "))

#processamento
media = (num1 + num2)/2

#saida
print(f"A sua media é: {media}")
# Out:
# Digite sua primeira nota: 10
# Digite sua segunda nota: 8
# A sua media é: 9.0

# %% [markdown]
# ## Conversão de Moeda
# ![image.png](data:image/png;base64,...)

# %%
#entrada
dolar = float(input("Digite o valor do dólar: "))
reais = float(input("Digite o valor em reais "))

#processamento
valordolar = reais/dolar

#saida
print(f"A conversão fica ${valordolar}")
# Out:
# Digite o valor do dólar: 5
# Digite o valor em reais 100
# A conversão fica $20.0

# %% [markdown]
# ## Cálculo Comissão
# ![image.png](data:image/png;base64,...)

# %%
#entrada
valor = float(input("Digite o Valor da unidade: "))
qtde = float(input("Digite a quantidade: "))

#processamento
venda = valor * qtde
comissao = (venda*5)/100

#saida
print(f"A comissão do vendedor é de: {comissao}")
# Out:
# Digite o Valor da unidade: 150
# Digite a quantidade: 2
# A comissão do vendedor é de: 15.0

# %% [markdown]
# ## Exercício 1
# ![image.png](data:image/png;base64,...)

# %%
#entrada
valorcarro = float(input("Qual o valor do carro? "))

#processamento
imposto = (valorcarro*45/100)+valorcarro
distribuicao = (imposto*28/100)+imposto

#saida
print(f"O valor total do carro fica: {distribuicao}")
# Out:
# Qual o valor do carro? 25000
# O valor total do carro fica: 46400.0

# %% [markdown]
# ## Exercício 2
# ![image.png](data:image/png;base64,...)

# %%
#entrada
hora = float(input("Quantas horas são? " ))
minutos = float(input("Quantos minutos são? "))

#processamento
minutodec = minutos/60
segundo = hora + minutodec

#saida
print(f"O tempo em segundo fica: {segundo}")
# Out:
# Quantas horas são? 4
# Quantos minutos são? 23
# O tempo em segundo fica: 4.383333333333334

# %% [markdown]
# ## Exercício 3
# ![image.png](data:image/png;base64,...)

# %%
#entrada
hora = float(input("Quantas horas de trabalho: "))
minuto = float(input("E mais quantos minutos: "))
valorhor = float(input("Valor pago por hora: "))

#processamento
horasdec = hora + (minuto/60)
valornormal = horasdec * valorhor
valortotal = (valornormal*70/100)+valornormal

#saida
print(f" o valor normal é de: {valornormal}")
print(f"O valor pago em horas extra é: {valortotal}")
# Out:
# Quantas horas de trabalho: 15
# E mais quantos minutos: 45
# Valor pago por hora: 25
#  o valor normal é de: 393.75
# O valor pago em horas extra é: 669.375

# %% [markdown]
# ## Exercício 4
# ![image.png](data:image/png;base64,...)

# %%
#entrada
valor_investimento = float(input("Qual o valor de investimento: "))
taxa_juros = float(input("Qual a taxa anual: "))
periodo_anual = float(input("Qual o periodo anual que será aplicado: "))

#processamento
taxa = taxa_juros/100
montante = valor_investimento *(1+taxa)**periodo_anual

#saida
print(f"O valor investido terá retorno de: {montante}")
# Out:
# Qual o valor de investimento: 1000
# Qual a taxa anual: 6
# Qual o periodo anual que será aplicado: 5
# O valor investido terá retorno de: 1338.2255776000002

# %% [markdown]
# ## Exercício 5
# ![image.png](data:image/png;base64,...)

# %%
#entrada
conta = float(input("Qual é o valor da conta: "))
gorjeta = float(input("Qual o valor da gorjeta: "))
pessoas = float(input("Quantas pessoas vão pagar: "))

#processamento
total = (conta*10/100)+gorjeta
valor_pessoa = (total/pessoas)+gorjeta

#saida
print(f"O valor por pessoa é de: {valor_pessoa}")
# Out:
# Qual é o valor da conta: 200
# Qual o valor da gorjeta: 50
# Quantas pessoas vão pagar: 4
# O valor por pessoa é de: 67.5
